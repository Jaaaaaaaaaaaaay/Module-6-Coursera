# %% [markdown]
# #My Data Science Tools Notebook

# %% [markdown]
# ## Introduction
# This notebook was created as part of the final project for the Data Science Tools course. It contains examples of markdown and code cells used in a data science environment.

# %% [markdown]
# ## Data Science Languages
# Here are some popular programming languages used in Data Science:
# 1. Python
# 2. R
# 3. SQL
# 4. Julia
# 5. Scala

# %% [markdown]
# ## Data Science Libraries
# Commonly used libraries in Data Science include:
# 1. Pandas
# 2. NumPy
# 3. Scikit-learn
# 4. TensorFlow
# 5. Matplotlib
# 6. ggplot2 (for R)

# %% [markdown]
# ## Data Science Tools
#
# | Tool            | Description                     |
# |-----------------|---------------------------------|
# | Jupyter Notebook| Interactive code notebook       |
# | RStudio         | IDE for R programming           |
# | Apache Spark    | Big data processing framework   |
# | RapidMiner      | Data science platform            |

# %% [markdown]
# ## Examples of Arithmetic Expressions in Python
# Below are examples of using Python code to perform arithmetic operations.

# %%
# This is a simple arithmetic operation
(5 * 4) + 2

# %%
# Convert 200 minutes to hours
minutes = 200
hours = minutes / 60
hours

# %% [markdown]
# ## Objectives
# The objectives of this notebook are:
# - Demonstrate use of markdown in JupyterLite
# - Perform simple arithmetic using Python
# - List tools, libraries, and languages used in Data Science

# %% [markdown]
# ## Author
# **Hannon Noriele T. Soriano**
